# %%
sum3 = 0
sum5 = 0
sub = 0
for i in range(3,1000,3):
    sum3+=i
for j in range(5,1000,5):
    sum5+=j
for k in range(15,1000,15):
    sub += k
print sum3 + sum5 -sub
# Out:
# 233168

# %%
a = [1]
a.append(2)
i = 1
sum =0
while a[len(a)-1]<4000000:
    a.append(a[i]+a[i-1])
    i=i+1
for i in a:
    if i%2==0:
        print i
        sum += i
print "정답은 ",sum
# Out:
# 2
# 8
# 34
# 144
# 610
# 2584
# 10946
# 46368
# 196418
# 832040
# 3524578
# 정답은  4613732

# %%
sum = 600851475143
i = 2
while sum!=0:  
    if sum%i==0:
        sum = sum/i
        print i
    i=i+1
print 'the end'
