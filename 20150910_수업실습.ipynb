# %%
import math
print abs(math.ceil(-4.3))
# Out:
# 4.0

# %%
import math
x1 = 10
x2 = 20
y1 = 30
y2 = 40
print math.sqrt(math.pow(x1-x2,2)+math.pow(y1-y2,2))
# Out:
# 14.1421356237

# %% [markdown]
# math.ceil 은 천장합수이므로 올림이다 그렇기에 내장함수인 round를 사용하여야 한다.
